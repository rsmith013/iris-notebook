# %%
import iris
import matplotlib.pyplot as plt
import iris.plot as iplt

# %%
ds = iris.load_cube('/badc/ukcp18/data/land-cpm/uk/2.2km/rcp85/01/pr/day/latest/pr_rcp85_land-cpm_uk_2.2km_01_day_19801201-19811130.nc')

# %%
ds
# Out:
# <iris 'Cube' of lwe_precipitation_rate / (mm/day) (ensemble_member: 1; time: 360; grid_latitude: 606; grid_longitude: 484)>

# %%
ds[0][0]
# Out:
# <iris 'Cube' of lwe_precipitation_rate / (mm/day) (grid_latitude: 606; grid_longitude: 484)>

# %%
plt.subplot(1,1,1)
iplt.pcolormesh(ds.pr)
ax = plt.gca()
ax.coastlines()
ax.gridlines()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-85314f443f11> in <module>
#       2
#       3 plt.subplot(1,1,1)
# ----> 4 iplt.pcolormesh(ds.pr)
#       5 ax = plt.gca()
#       6 ax.coastlines()
#
# AttributeError: 'Cube' object has no attribute 'pr'
